# %% [markdown]
# # Yellow Taxi Trip Data: Trip Duration Prediction

# %% [markdown]
# ### **Task Description**
#
# The task is to use the taxi trip dataset to implement a model that given any feature of your choice, should predict the trip duration.

# %% [markdown]
# ### **Process**
# - Data Ingestion: This entails loading the sample data generated from the raw data.
# - Exploratory Data Analysis: Univariate and Bivariate analysis of the features
# - Feature Engineering: Feature creation and feature scaling
# - Feature Selection: Using lasso regression to select the best features to use for modelling
# - Model Building: Building a model to predict trip duration and evaluating the model using cross validation and Grid Search CV to obtain the best model and it's best parameters.
# - Model Deployment: Creating an app to use for prediction based on the saved model.

# %% [markdown]
# ### Results
#
# - After feature engineering & feature selection the following features were selected to be used to build a model to predict trip duration. ['trip_distance', 'RatecodeID', 'DOLocationID', 'payment_type','fare_amount', 'extra', 'total_amount', 'pickup_day_no', 'pickup_hour'].
# - A baseline model was built using Linear Regression() with a mean squared error of 0.000035 and a r2 score of 1, the model had a tendency to overfit due to the total_amount feature. This feature was removed and the model built the other features. The model's r2 score was 6,18

# %% [markdown]
# ### Data Ingestion
#
# Loading the raw data from the downloaded csv file

# %%
#importing necessary libs
import numpy as np
import pandas as pd

#data visualisation
import seaborn as sns     
sns.set_theme(palette='deep')
import matplotlib.pyplot as plt
# %matplotlib inline
#import plotly.express as px

#import datetime as dt
#import warnings; warnings.simplefilter('ignore')

# %%
#Loading data from the csv file/loading the sample data
dataset = pd.read_csv("..\Data\Yellow_Taxi_Trip_Sample.csv")

# %%
dataset.shape
# Out:
# (1134081, 18)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1134081 entries, 0 to 1134080
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1134081 non-null  int64
#  1   VendorID               1134081 non-null  int64
#  2   tpep_pickup_datetime   1134081 non-null  object
#  3   tpep_dropoff_datetime  1134081 non-null  object
#  4   passenger_count        1134081 non-null  int64
#  5   trip_distance          1134081 non-null  float64
#  6   RatecodeID             1134081 non-null  int64
#  7   store_and_fwd_flag     1134081 non-null  object
#  8   PULocationID           1134081 non-null  int64
#  9   DOLocationID           1134081 non-null  int64
#  10  payment_type           1134081 non-null  int64
#  11  fare_amount            1134081 non-null  float64
#  12  extra                  1134081 non-null  float64
#  13  mta_tax                1134081 non-null  float64
#  14  tip_amount             1134081 non-null  float64
#  15  tolls_amount           1134081 non-null  float64
#  16  improvement_surcharge  1134081 non-null  float64
#  17  total_amount           1134081 non-null  float64
# dtypes: float64(8), int64(7), object(3)
# memory usage: 155.7+ MB

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
dataset.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0           0         2  07/27/2017 06:31:15 PM  07/27/2017 06:48:44 PM
# 1           1         1  07/27/2017 06:53:08 PM  07/27/2017 07:09:18 PM
# 2           2         1  07/27/2017 06:34:32 PM  07/27/2017 06:39:44 PM
# 3           3         2  07/27/2017 06:55:28 PM  07/27/2017 07:06:33 PM
# 4           4         2  07/27/2017 06:20:18 PM  07/27/2017 06:32:35 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                2           2.25           1                  N
# 1                1           1.80           1                  N
# 2                1           0.60           1                  N
# 3                2           1.01           1                  N
# 4                1           1.18           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           230           246             2         13.0    1.0      0.5
# 1           246           230             1         11.5    1.0      0.5
# 2           141           262             1          5.0    1.0      0.5
# 3            43           141             2          8.0    1.0      0.5
# 4            48           164             2          9.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0         0.0           0.0                    0.3          14.8
# 1         2.0           0.0                    0.3          15.3
# 2         1.0           0.0                    0.3           7.8
# 3         0.0           0.0                    0.3           9.8
# 4         0.0           0.0                    0.3          10.8

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
#dropping the unamed column
dataset.drop(['Unnamed: 0'],inplace=True,axis=1)

# %% [markdown]
# **The following are the column descriptions:**
# - VendorID: A code indicating the TPEP provider that provided the record.
# - tpep_pickup_datetime: The date and time when the meter was engaged.
# - tpep_dropoff_datetime: The date and time when the meter was disengaged.
# - passenger_count: The number of passengers in the vehicle.
# - trip_distance: The elapsed trip distance in miles reported by the taximeter.
# - RatecodeID: The final rate code in effect at the end of the trip.
# - store_and_fwd_flag: This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka “store and forward,” because the vehicle did not have a connection to the server.
# - PULocationID: TLC Taxi Zone in which the taximeter was engaged
# - DOLocationID: TLC Taxi Zone in which the taximeter was disengaged
# - payment_type: A numeric code signifying how the passenger paid for the trip.
# - fare_amount: The time-and-distance fare calculated by the meter.
# - extra: Miscellaneous extras and surcharges.
# - mta_tax: Tax that is automatically triggered based on the metered rate in use.
# - tip_amount: Tip amount – This field is automatically populated for credit card tips. Cash tips are not included.
# - tolls_amount: Total amount of all tolls paid in trip.
# - improvement_surcharge: Improvement surcharge assessed trips at the flag drop
# - total_amount: The total amount charged to passengers. Does not include cash tips.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In the EDA section, we analyse the data to find out the following:
# - Missing values
# - Duplicated records
# - Distribution of numerical values
# - Cardinality of categorical variables
# - Outliers
# - Relationship between independent and the dependent variable

# %% [markdown]
# ### EDA
#
# We start the process by cleaning the data e.g. checking for null values, duplicates and filtering out records/rows that are not relevant for the analysis.

# %%
data = dataset.copy()

# %%
data.head()
# Out:
#    VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0         2  07/27/2017 06:31:15 PM  07/27/2017 06:48:44 PM                2
# 1         1  07/27/2017 06:53:08 PM  07/27/2017 07:09:18 PM                1
# 2         1  07/27/2017 06:34:32 PM  07/27/2017 06:39:44 PM                1
# 3         2  07/27/2017 06:55:28 PM  07/27/2017 07:06:33 PM                2
# 4         2  07/27/2017 06:20:18 PM  07/27/2017 06:32:35 PM                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.25           1                  N           230           246
# 1           1.80           1                  N           246           230
# 2           0.60           1                  N           141           262
# 3           1.01           1                  N            43           141
# 4           1.18           1                  N            48           164
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         13.0    1.0      0.5         0.0           0.0
# 1             1         11.5    1.0      0.5         2.0           0.0
# 2             1          5.0    1.0      0.5         1.0           0.0
# 3             2          8.0    1.0      0.5         0.0           0.0
# 4             2          9.0    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          14.8
# 1                    0.3          15.3
# 2                    0.3           7.8
# 3                    0.3           9.8
# 4                    0.3          10.8

# %%
data.shape
# Out:
# (1134081, 17)

# %%
data.nunique()
# Out:
# VendorID                       2
# tpep_pickup_datetime     1109575
# tpep_dropoff_datetime    1109699
# passenger_count               10
# trip_distance               3153
# RatecodeID                     7
# store_and_fwd_flag             2
# PULocationID                 246
# DOLocationID                 261
# payment_type                   4
# fare_amount                  697
# extra                         14
# mta_tax                        8
# tip_amount                  2145
# tolls_amount                 405
# improvement_surcharge          4
# total_amount                6407
# dtype: int64

# %%
#How many vendors?
data["VendorID"].value_counts()
# Out:
# VendorID
# 2    622773
# 1    511308
# Name: count, dtype: int64

# %% [markdown]
# **Converting pickup & dropoff columns to datetime datatype**

# %%
#Converting to datetime
data["tpep_pickup_datetime"] = pd.to_datetime(data["tpep_pickup_datetime"])
data["tpep_dropoff_datetime"] = pd.to_datetime(data["tpep_dropoff_datetime"])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23936\3691569389.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["tpep_pickup_datetime"] = pd.to_datetime(data["tpep_pickup_datetime"])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23936\3691569389.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["tpep_dropoff_datetime"] = pd.to_datetime(data["tpep_dropoff_datetime"])

# %%
#What is the period of the extracted data?
data["tpep_pickup_datetime"].min(),data["tpep_pickup_datetime"].max()
# Out:
# (Timestamp('2008-12-31 23:38:06'), Timestamp('2017-12-31 23:59:50'))

# %%
data.describe()
# Out:
#            VendorID           tpep_pickup_datetime  \
# count  1.134081e+06                        1134081
# mean   1.549143e+00  2017-06-29 10:03:27.408774912
# min    1.000000e+00            2008-12-31 23:38:06
# 25%    1.000000e+00            2017-03-29 21:20:46
# 50%    2.000000e+00            2017-06-23 18:14:12
# 75%    2.000000e+00            2017-10-01 15:52:48
# max    2.000000e+00            2017-12-31 23:59:50
# std    4.975793e-01                            NaN
#
#                tpep_dropoff_datetime  passenger_count  trip_distance  \
# count                        1134081     1.134081e+06   1.134081e+06
# mean   2017-06-29 10:20:00.083175168     1.624075e+00   2.927934e+00
# min              2008-12-31 23:49:30     0.000000e+00   0.000000e+00
# 25%              2017-03-29 21:34:42     1.000000e+00   9.900000e-01
# 50%              2017-06-23 18:34:42     1.000000e+00   1.620000e+00
# 75%              2017-10-01 16:10:09     2.000000e+00   3.040000e+00
# max              2018-01-01 21:46:07     9.000000e+00   1.287000e+02
# std                              NaN     1.263473e+00   3.735205e+00
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  1.134081e+06  1.134081e+06  1.134081e+06  1.134081e+06  1.134081e+06
# mean   1.044371e+00  1.628480e+02  1.608200e+02  1.336074e+00  1.297619e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00 -3.000000e+02
# 25%    1.000000e+00  1.140000e+02  1.070000e+02  1.000000e+00  6.500000e+00
# 50%    1.000000e+00  1.620000e+02  1.620000e+02  1.000000e+00  9.500000e+00
# 75%    1.000000e+00  2.330000e+02  2.330000e+02  2.000000e+00  1.450000e+01
# max    9.900000e+01  2.650000e+02  2.650000e+02  4.000000e+00  8.300000e+02
# std    5.779506e-01  6.654028e+01  7.048411e+01  4.928072e-01  1.140789e+01
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  1.134081e+06  1.134081e+06  1.134081e+06  1.134081e+06
# mean   3.309229e-01  4.972829e-01  1.839390e+00  3.256813e-01
# min   -4.500000e+00 -5.000000e-01 -1.146000e+01  0.000000e+00
# 25%    0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  5.000000e-01  1.360000e+00  0.000000e+00
# 75%    5.000000e-01  5.000000e-01  2.450000e+00  0.000000e+00
# max    4.500000e+00  6.246000e+01  3.155600e+02  8.958900e+02
# std    4.523131e-01  7.104536e-02  2.609286e+00  1.887977e+00
#
#        improvement_surcharge  total_amount
# count           1.134081e+06  1.134081e+06
# mean            2.996232e-01  1.627311e+01
# min            -3.000000e-01 -3.008000e+02
# 25%             3.000000e-01  8.580000e+00
# 50%             3.000000e-01  1.180000e+01
# 75%             3.000000e-01  1.780000e+01
# max             1.000000e+00  9.486900e+02
# std             1.439590e-02  1.413021e+01

# %%
#Checking to see of there are any null values
data.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
#checking to see if there are any duplicated records
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Based on the above, there are no duplicate records/rows and no null values

# %%
#checking if there are records wih trip_distance ==0
sum(data['trip_distance']==0)
# Out:
# 7405

# %%
data[data['trip_distance']==0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 176             2  2017-07-27 18:55:04   2017-07-27 18:55:20                6
# 265             1  2017-07-27 19:53:29   2017-07-27 19:54:38                1
# 271             1  2017-07-27 19:49:33   2017-07-27 19:50:27                1
# 317             1  2017-07-27 19:23:34   2017-07-27 19:23:39                1
# 721             2  2017-07-27 21:01:49   2017-07-27 21:01:51                1
# ...           ...                  ...                   ...              ...
# 1133387         2  2017-07-27 13:36:35   2017-07-27 13:36:56                5
# 1133452         1  2017-07-27 14:37:56   2017-07-27 14:38:16                1
# 1133579         2  2017-07-27 15:41:49   2017-07-27 15:42:00                2
# 1133655         2  2017-07-27 15:30:10   2017-07-27 15:30:15                1
# 1133850         2  2017-07-27 16:50:49   2017-07-27 16:51:18                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 176                0.0           1                  N           161
# 265                0.0           1                  N           138
# 271                0.0           1                  N           114
# 317                0.0           1                  N           148
# 721                0.0           5                  N           264
# ...                ...         ...                ...           ...
# 1133387            0.0           1                  N           264
# 1133452            0.0           5                  N           265
# 1133579            0.0           5                  N           166
# 1133655            0.0           1                  N            43
# 1133850            0.0           1                  N            83
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 176               164             1          2.5    1.0      0.5        0.00
# 265               138             4          3.0    1.0      0.5        0.00
# 271               114             2          2.5    1.0      0.5        0.00
# 317               148             3          2.5    1.0      0.5        0.00
# 721               161             1         63.0    0.0      0.5       12.76
# ...               ...           ...          ...    ...      ...         ...
# 1133387           193             2          2.5    0.0      0.5        0.00
# 1133452           265             1        164.0    0.0      0.0       32.85
# 1133579           166             1         60.0    0.0      0.0       15.08
# 1133655            43             2          2.5    0.0      0.5        0.00
# 1133850            83             2          2.5    1.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount
# 176               0.0                    0.3          4.30
# 265               0.0                    0.3          4.80
# 271               0.0                    0.3          4.30
# 317               0.0                    0.3          4.30
# 721               0.0                    0.3         76.56
# ...               ...                    ...           ...
# 1133387           0.0                    0.3          3.30
# 1133452           0.0                    0.3        197.15
# 1133579           0.0                    0.3         75.38
# 1133655           0.0                    0.3          3.30
# 1133850           0.0                    0.3          4.30
#
# [7405 rows x 17 columns]

# %%
data['trip_distance'].value_counts()
# Out:
# trip_distance
# 0.90     26360
# 0.80     25893
# 1.00     25659
# 0.70     24709
# 1.10     24432
#          ...
# 31.43        1
# 27.97        1
# 28.42        1
# 33.48        1
# 29.42        1
# Name: count, Length: 3153, dtype: int64

# %% [markdown]
# Seems from above there are records where the trip distance==0,

# %% [markdown]
# ### Feature Creation
#
# This step entails creating new features from existing variables to gain more insights from the data.

# %% [markdown]
# **Trip Duration**
#
# Calculating the trip duration in minutes using the drop-off and pick up times

# %%
#calculating trip duration(in minutes) using pickup & dropoff times
data['trip_duration'] = (data["tpep_dropoff_datetime"] - data["tpep_pickup_datetime"]).dt.total_seconds() / 60

# %%
data['trip_duration']
# Out:
# 0          17.483333
# 1          16.166667
# 2           5.200000
# 3          11.083333
# 4          12.283333
#              ...
# 1134076    12.083333
# 1134077     3.800000
# 1134078    20.083333
# 1134079     5.650000
# 1134080    33.150000
# Name: trip_duration, Length: 1134081, dtype: float64

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-07-27 18:31:15   2017-07-27 18:48:44                2
# 1         1  2017-07-27 18:53:08   2017-07-27 19:09:18                1
# 2         1  2017-07-27 18:34:32   2017-07-27 18:39:44                1
# 3         2  2017-07-27 18:55:28   2017-07-27 19:06:33                2
# 4         2  2017-07-27 18:20:18   2017-07-27 18:32:35                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.25           1                  N           230           246
# 1           1.80           1                  N           246           230
# 2           0.60           1                  N           141           262
# 3           1.01           1                  N            43           141
# 4           1.18           1                  N            48           164
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         13.0    1.0      0.5         0.0           0.0
# 1             1         11.5    1.0      0.5         2.0           0.0
# 2             1          5.0    1.0      0.5         1.0           0.0
# 3             2          8.0    1.0      0.5         0.0           0.0
# 4             2          9.0    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  trip_duration
# 0                    0.3          14.8      17.483333
# 1                    0.3          15.3      16.166667
# 2                    0.3           7.8       5.200000
# 3                    0.3           9.8      11.083333
# 4                    0.3          10.8      12.283333

# %% [markdown]
# **Day of the week,Time of day and the hour**

# %%
data['pickup_day']=data['tpep_pickup_datetime'].dt.day_name()
data['dropoff_day']=data['tpep_dropoff_datetime'].dt.day_name()
data['pickup_day_no']=data['tpep_pickup_datetime'].dt.weekday
data['dropoff_day_no']=data['tpep_dropoff_datetime'].dt.weekday
data['pickup_hour']=data['tpep_pickup_datetime'].dt.hour
data['dropoff_hour']=data['tpep_dropoff_datetime'].dt.hour
data['pickup_month']=data['tpep_pickup_datetime'].dt.month
data['dropoff_month']=data['tpep_dropoff_datetime'].dt.month

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-07-27 18:31:15   2017-07-27 18:48:44                2
# 1         1  2017-07-27 18:53:08   2017-07-27 19:09:18                1
# 2         1  2017-07-27 18:34:32   2017-07-27 18:39:44                1
# 3         2  2017-07-27 18:55:28   2017-07-27 19:06:33                2
# 4         2  2017-07-27 18:20:18   2017-07-27 18:32:35                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.25           1                  N           230           246
# 1           1.80           1                  N           246           230
# 2           0.60           1                  N           141           262
# 3           1.01           1                  N            43           141
# 4           1.18           1                  N            48           164
#
#    payment_type  ...  total_amount  trip_duration  pickup_day  dropoff_day  \
# 0             2  ...          14.8      17.483333    Thursday     Thursday
# 1             1  ...          15.3      16.166667    Thursday     Thursday
# 2             1  ...           7.8       5.200000    Thursday     Thursday
# 3             2  ...           9.8      11.083333    Thursday     Thursday
# 4             2  ...          10.8      12.283333    Thursday     Thursday
#
#    pickup_day_no  dropoff_day_no  pickup_hour  dropoff_hour pickup_month  \
# 0              3               3           18            18            7
# 1              3               3           18            19            7
# 2              3               3           18            18            7
# 3              3               3           18            19            7
# 4              3               3           18            18            7
#
#   dropoff_month
# 0             7
# 1             7
# 2             7
# 3             7
# 4             7
#
# [5 rows x 26 columns]

# %%
#Function to determine the time of day
def time_of_day(x):
    if x in range(6,12):
        return 'Morning'
    elif x in range(12,16):
        return 'Afternoon'
    elif x in range(16,22):
        return 'Evening'
    else:
        return 'Late night'

# %%
data['pickup_timeofday']=data['pickup_hour'].apply(time_of_day)
data['dropoff_timeofday']=data['dropoff_hour'].apply(time_of_day)

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# **Target Variable: Trip Duration**
#
# To Note: With Trip duration as our target variable, we'll use only the pickup time as the independent variable and ignore the drop-off time.

# %%
sns.histplot(data['trip_duration'],kde=False,bins=200)
# Out:
# <Axes: xlabel='trip_duration', ylabel='Count'>

# %% [markdown]
# From above we can observe that the distribution is skewed

# %%
sns.boxplot(data['trip_duration'])
# Out:
# <Axes: ylabel='trip_duration'>

# %%
#What is the mean of the trip duration
data['trip_duration'].mean()
# Out:
# 16.544573330006113

# %%
#What is the medium
data['trip_duration'].median()
# Out:
# 11.166666666666666

# %%
data['trip_duration'].value_counts()
# Out:
# trip_duration
# 5.633333       1241
# 6.966667       1232
# 5.966667       1229
# 7.483333       1228
# 5.983333       1211
#                ...
# 303.966667        1
# 1413.283333       1
# 1402.316667       1
# 1394.650000       1
# 74.700000         1
# Name: count, Length: 7488, dtype: int64

# %%
data['trip_duration'].sort_values(ascending=False)
# Out:
# 562559    1439.650000
# 629264    1439.650000
# 432201    1439.600000
# 135149    1439.600000
# 612871    1439.550000
#              ...
# 297017     -37.150000
# 297173     -41.800000
# 297217     -44.783333
# 296986     -52.216667
# 297117     -55.100000
# Name: trip_duration, Length: 1134081, dtype: float64

# %%
data[data['trip_duration']==0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 954             1  2017-07-27 23:49:52   2017-07-27 23:49:52                1
# 1190            2  2017-07-28 00:00:00   2017-07-28 00:00:00                2
# 2414            1  2017-07-28 13:43:04   2017-07-28 13:43:04                1
# 2551            1  2017-07-28 13:23:55   2017-07-28 13:23:55                1
# 2808            1  2017-07-28 15:48:50   2017-07-28 15:48:50                1
# ...           ...                  ...                   ...              ...
# 1126145         1  2017-07-25 00:32:21   2017-07-25 00:32:21                1
# 1127686         1  2017-07-25 15:47:06   2017-07-25 15:47:06                1
# 1128611         1  2017-07-25 21:09:38   2017-07-25 21:09:38                1
# 1131181         1  2017-07-26 19:51:38   2017-07-26 19:51:38                1
# 1132972         1  2017-07-27 11:39:54   2017-07-27 11:39:54                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 954               0.00           1                  N            90
# 1190             21.29           2                  N           132
# 2414              0.00           1                  N           261
# 2551              0.00           1                  N           264
# 2808              0.00           5                  N           132
# ...                ...         ...                ...           ...
# 1126145           0.00           1                  N           145
# 1127686           0.00           1                  N           249
# 1128611           0.00           1                  Y            79
# 1131181           0.00           1                  N           140
# 1132972           0.00           2                  N           132
#
#          DOLocationID  payment_type  ...  pickup_day  dropoff_day  \
# 954               264             2  ...    Thursday     Thursday
# 1190               48             2  ...      Friday       Friday
# 2414              264             2  ...      Friday       Friday
# 2551              264             2  ...      Friday       Friday
# 2808              264             2  ...      Friday       Friday
# ...               ...           ...  ...         ...          ...
# 1126145           264             2  ...     Tuesday      Tuesday
# 1127686           264             2  ...     Tuesday      Tuesday
# 1128611           264             2  ...     Tuesday      Tuesday
# 1131181           264             2  ...   Wednesday    Wednesday
# 1132972           264             2  ...    Thursday     Thursday
#
#          pickup_day_no  dropoff_day_no  pickup_hour  dropoff_hour  \
# 954                  3               3           23            23
# 1190                 4               4            0             0
# 2414                 4               4           13            13
# 2551                 4               4           13            13
# 2808                 4               4           15            15
# ...                ...             ...          ...           ...
# 1126145              1               1            0             0
# 1127686              1               1           15            15
# 1128611              1               1           21            21
# 1131181              2               2           19            19
# 1132972              3               3           11            11
#
#          pickup_month  dropoff_month pickup_timeofday dropoff_timeofday
# 954                 7              7       Late night        Late night
# 1190                7              7       Late night        Late night
# 2414                7              7        Afternoon         Afternoon
# 2551                7              7        Afternoon         Afternoon
# 2808                7              7        Afternoon         Afternoon
# ...               ...            ...              ...               ...
# 1126145             7              7       Late night        Late night
# 1127686             7              7        Afternoon         Afternoon
# 1128611             7              7          Evening           Evening
# 1131181             7              7          Evening           Evening
# 1132972             7              7          Morning           Morning
#
# [1045 rows x 28 columns]

# %%
sum(data['trip_duration']==0)
# Out:
# 1045

# %% [markdown]
# The highest trip duration is about 1440 minutes, that's about 24 hours. We can also observe cases where the trip duration is set to 0 minutes. It's worth investigating further to check this trips against the trip distance and the total amount charged for the trip.
#
# In such cases where trip duration==0 & trip distance==0 we can drop such records: This can be situations where the trip was cancelled

# %% [markdown]
# **Vendor ID**

# %%
data['VendorID'].value_counts()
# Out:
# VendorID
# 2    622773
# 1    511308
# Name: count, dtype: int64

# %%
sns.countplot(x='VendorID',data=data)
# Out:
# <Axes: xlabel='VendorID', ylabel='count'>

# %% [markdown]
# **Passenger Count**
#
# What is the distribution of passenger counts across the trips?

# %%
data['passenger_count'].value_counts()
# Out:
# passenger_count
# 1    810268
# 2    164852
# 5     54099
# 3     47473
# 6     33019
# 4     22691
# 0      1670
# 7         4
# 8         4
# 9         1
# Name: count, dtype: int64

# %% [markdown]
# - Seems there are records with 0 passenger counts. This will need to be removed.
# - Seems a high percentage of the trips had 1 passenger

# %% [markdown]
# **Store and Forward Flag**

# %%
data['store_and_fwd_flag'].value_counts(normalize=True)
# Out:
# store_and_fwd_flag
# N    0.995765
# Y    0.004235
# Name: proportion, dtype: float64

# %% [markdown]
# Seems there are less than 1% of the trips that were stored before forwarding

# %% [markdown]
# **Trip Distance**
#
# Trip distance is measured in miles

# %%
#Getting the distribution of trip distance
data['trip_distance'].value_counts()
# Out:
# trip_distance
# 0.90     26360
# 0.80     25893
# 1.00     25659
# 0.70     24709
# 1.10     24432
#          ...
# 31.43        1
# 27.97        1
# 28.42        1
# 33.48        1
# 29.42        1
# Name: count, Length: 3153, dtype: int64

# %%
sns.histplot(data['trip_distance'],kde=False,bins=200)
# Out:
# <Axes: xlabel='trip_distance', ylabel='Count'>

# %%
data['trip_distance'].mean(),data['trip_distance'].median()
# Out:
# (2.9279336837492194, 1.62)

# %%
sns.boxplot(data['trip_distance'])
# Out:
# <Axes: ylabel='trip_distance'>

# %% [markdown]
# The average trip distance is about 3 miles with a median of about 1.6 miles

# %% [markdown]
# **Trip per Day**
#
# Understanding the distribution of the trips per day of the week

# %%
figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(20,5))
ax1.set_title('Pickup Days')
ax=sns.countplot(x="pickup_day",data=data,ax=ax1)
ax2.set_title('Dropoff Days')
ax=sns.countplot(x="dropoff_day",data=data,ax=ax2)

# %% [markdown]
# We observe that Friday is the busiest followed by Saturday probably because it's a weekend. Mondays have the least number of trips

# %% [markdown]
# **Trips per Hour**

# %%
figure,(ax9,ax10)=plt.subplots(ncols=2,figsize=(20,5))
ax9.set_title('Pickup Days')
ax=sns.countplot(x="pickup_hour",data=data,ax=ax9)
ax10.set_title('Dropoff Days')
ax=sns.countplot(x="dropoff_hour",data=data,ax=ax10)

# %% [markdown]
# **Trips per Time of Day**

# %%
figure,(ax3,ax4)=plt.subplots(ncols=2,figsize=(20,5))
ax3.set_title('Pickup Time of Day')
ax=sns.countplot(x="pickup_timeofday",data=data,ax=ax3)
ax4.set_title('Dropoff Time of Day')
ax=sns.countplot(x="dropoff_timeofday",data=data,ax=ax4)

# %% [markdown]
# We observe that the busiest hours are between 6pm to 8pm. In the evenings

# %% [markdown]
# **Trips per Month**

# %%
figure,(ax11,ax12)=plt.subplots(ncols=2,figsize=(20,5))
ax11.set_title('Pickup Month')
ax=sns.countplot(x="pickup_month",data=data,ax=ax11)
ax12.set_title('Dropoff Month')
ax=sns.countplot(x="dropoff_month",data=data,ax=ax12)

# %%
data['pickup_month'].value_counts()
# Out:
# pickup_month
# 3     102245
# 5     101338
# 4     100542
# 10     97730
# 1      97158
# 6      96397
# 12     94712
# 11     92774
# 2      91731
# 9      89281
# 7      86183
# 8      83990
# Name: count, dtype: int64

# %% [markdown]
# There's generally not much difference in the number of trips accross the months.

# %% [markdown]
# **Rate Code**

# %%
data['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1     1101841
# 2       25315
# 5        3867
# 3        2406
# 4         616
# 99         29
# 6           7
# Name: count, dtype: int64

# %% [markdown]
# We can observe a high number of the trips use Standard Rate

# %% [markdown]
# **Payment Type**

# %%
data['payment_type'].value_counts(normalize=True)
# Out:
# payment_type
# 1    0.672237
# 2    0.321007
# 3    0.005202
# 4    0.001555
# Name: proportion, dtype: float64

# %% [markdown]
# We can observe more than 99% of the trips are credit & cash based.

# %% [markdown]
# **Pickup Location ID**
#
# Understanding the distribution of the trips across the pickup locations

# %%
data['PULocationID'].value_counts()
# Out:
# PULocationID
# 237    44329
# 161    42584
# 236    40034
# 186    39600
# 230    38638
#        ...
# 251        1
# 117        1
# 5          1
# 253        1
# 118        1
# Name: count, Length: 246, dtype: int64

# %%
data['DOLocationID'].value_counts()
# Out:
# DOLocationID
# 161    42053
# 236    41679
# 237    38533
# 170    36120
# 230    34874
#        ...
# 176        3
# 187        3
# 105        2
# 2          1
# 99         1
# Name: count, Length: 261, dtype: int64

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# We'll try to understand the relationship between the independent variables and the target variable

# %% [markdown]
# **Trip Duration per Vendor**

# %%
sns.barplot(y='trip_duration',x='VendorID',data=data,estimator=np.mean)
# Out:
# <Axes: xlabel='VendorID', ylabel='trip_duration'>

# %% [markdown]
# Seems like vendor 2 takes slightly longer trips than vendor 1

# %% [markdown]
# **Trip Duration per Store and Forward Flag**

# %%
sns.set_theme(palette='deep')
sns.catplot(y='trip_duration',x='store_and_fwd_flag',data=data,kind='strip')

# %% [markdown]
# **Trip Duration per passenger count**

# %%
sns.catplot(y='trip_duration',x='passenger_count',data=data,kind='strip')

# %% [markdown]
# We can observe that there seems to be no visible relationship between trip duration and passenger count

# %% [markdown]
# **Trip Duration per Hour**

# %%
sns.lineplot(x='pickup_hour',y='trip_duration',data=data)
# Out:
# <Axes: xlabel='pickup_hour', ylabel='trip_duration'>

# %% [markdown]
# We can observe there is a relationship between trip duration and the pickup time,with the afternoon have the highest maybe due to more traffic on thr road.
# The lowest time duration is oberved in the morning

# %% [markdown]
# **Trip Duration per Day of Week**

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-07-27 18:31:15   2017-07-27 18:48:44                2
# 1         1  2017-07-27 18:53:08   2017-07-27 19:09:18                1
# 2         1  2017-07-27 18:34:32   2017-07-27 18:39:44                1
# 3         2  2017-07-27 18:55:28   2017-07-27 19:06:33                2
# 4         2  2017-07-27 18:20:18   2017-07-27 18:32:35                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.25           1                  N           230           246
# 1           1.80           1                  N           246           230
# 2           0.60           1                  N           141           262
# 3           1.01           1                  N            43           141
# 4           1.18           1                  N            48           164
#
#    payment_type  ...  pickup_day  dropoff_day  pickup_day_no  dropoff_day_no  \
# 0             2  ...    Thursday     Thursday              3               3
# 1             1  ...    Thursday     Thursday              3               3
# 2             1  ...    Thursday     Thursday              3               3
# 3             2  ...    Thursday     Thursday              3               3
# 4             2  ...    Thursday     Thursday              3               3
#
#    pickup_hour  dropoff_hour  pickup_month  dropoff_month pickup_timeofday  \
# 0           18            18             7              7          Evening
# 1           18            19             7              7          Evening
# 2           18            18             7              7          Evening
# 3           18            19             7              7          Evening
# 4           18            18             7              7          Evening
#
#   dropoff_timeofday
# 0           Evening
# 1           Evening
# 2           Evening
# 3           Evening
# 4           Evening
#
# [5 rows x 28 columns]

# %%
sns.lineplot(x='pickup_day',y='trip_duration',data=data)
# Out:
# <Axes: xlabel='pickup_day', ylabel='trip_duration'>

# %% [markdown]
# We can observe the trip duration is longest on Thursdays

# %% [markdown]
# **Trip Duration per Month**

# %%
sns.lineplot(x='pickup_month',y='trip_duration',data=data)
# Out:
# <Axes: xlabel='pickup_month', ylabel='trip_duration'>

# %% [markdown]
# We can observe the trip duration increases from Feb every month

# %% [markdown]
# **Trip Duration & Distance**

# %%
sns.scatterplot(y='trip_distance',x='trip_duration',data=data)
# Out:
# <Axes: xlabel='trip_duration', ylabel='trip_distance'>

# %% [markdown]
# We can observe there are trips which have longer durations yet the distance is less, this could be due to traffic

# %% [markdown]
# **Trip Duration & Total Amount**

# %%
sns.scatterplot(y='trip_duration',x='total_amount',data=data)
# Out:
# <Axes: xlabel='total_amount', ylabel='trip_duration'>

# %% [markdown]
# **Checking Correlation**

# %%
data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'trip_duration', 'pickup_day', 'dropoff_day',
#        'pickup_day_no', 'dropoff_day_no', 'pickup_hour', 'dropoff_hour',
#        'pickup_month', 'dropoff_month', 'pickup_timeofday',
#        'dropoff_timeofday'],
#       dtype='object')

# %%
df = data[['VendorID','passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag','PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount','pickup_day', 'dropoff_day',
       'pickup_day_no', 'dropoff_day_no', 'pickup_hour', 'dropoff_hour',
       'pickup_month', 'dropoff_month', 'pickup_timeofday',
       'dropoff_timeofday', 'trip_duration']]

# %%
#getting correlation features in the dataset
corrmat = df.corr(numeric_only = True)
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plotting heatmap
g = sns.heatmap(df.corr(numeric_only = True),annot = True,cmap="RdYlGn")

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# The following process:
# - Drop records where the trip duration==0 & trip_distance==0 & total amount ==0 , passenger_count=0
# - Split Dependent & Independent variables
# - Drop columns that are not needed for the prediction: [drop-off time]Feature Creation
# - Log transformation of numerical variables;
# - Which are the useful features in predicting trip duration: VendorID,pickup_hour,day_of week

# %%
dataset_ = dataset.copy()

# %%
dataset_.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0           0         2  07/27/2017 06:31:15 PM  07/27/2017 06:48:44 PM
# 1           1         1  07/27/2017 06:53:08 PM  07/27/2017 07:09:18 PM
# 2           2         1  07/27/2017 06:34:32 PM  07/27/2017 06:39:44 PM
# 3           3         2  07/27/2017 06:55:28 PM  07/27/2017 07:06:33 PM
# 4           4         2  07/27/2017 06:20:18 PM  07/27/2017 06:32:35 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                2           2.25           1                  N
# 1                1           1.80           1                  N
# 2                1           0.60           1                  N
# 3                2           1.01           1                  N
# 4                1           1.18           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           230           246             2         13.0    1.0      0.5
# 1           246           230             1         11.5    1.0      0.5
# 2           141           262             1          5.0    1.0      0.5
# 3            43           141             2          8.0    1.0      0.5
# 4            48           164             2          9.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0         0.0           0.0                    0.3          14.8
# 1         2.0           0.0                    0.3          15.3
# 2         1.0           0.0                    0.3           7.8
# 3         0.0           0.0                    0.3           9.8
# 4         0.0           0.0                    0.3          10.8

# %%
#Converting to datetime
dataset_["tpep_pickup_datetime"] = pd.to_datetime(dataset_["tpep_pickup_datetime"])
dataset_["tpep_dropoff_datetime"] = pd.to_datetime(dataset_["tpep_dropoff_datetime"])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21568\832130358.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset_["tpep_pickup_datetime"] = pd.to_datetime(dataset_["tpep_pickup_datetime"])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21568\832130358.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset_["tpep_dropoff_datetime"] = pd.to_datetime(dataset_["tpep_dropoff_datetime"])

# %%
#calculating trip duration(in minutes) using pickup & dropoff times
dataset_['trip_duration'] = (dataset_["tpep_dropoff_datetime"] - dataset_["tpep_pickup_datetime"]).dt.total_seconds() / 60

# %%
dataset_.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         2  2017-07-27 18:31:15   2017-07-27 18:48:44
# 1           1         1  2017-07-27 18:53:08   2017-07-27 19:09:18
# 2           2         1  2017-07-27 18:34:32   2017-07-27 18:39:44
# 3           3         2  2017-07-27 18:55:28   2017-07-27 19:06:33
# 4           4         2  2017-07-27 18:20:18   2017-07-27 18:32:35
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                2           2.25           1                  N
# 1                1           1.80           1                  N
# 2                1           0.60           1                  N
# 3                2           1.01           1                  N
# 4                1           1.18           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           230           246             2         13.0    1.0      0.5
# 1           246           230             1         11.5    1.0      0.5
# 2           141           262             1          5.0    1.0      0.5
# 3            43           141             2          8.0    1.0      0.5
# 4            48           164             2          9.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.0           0.0                    0.3          14.8
# 1         2.0           0.0                    0.3          15.3
# 2         1.0           0.0                    0.3           7.8
# 3         0.0           0.0                    0.3           9.8
# 4         0.0           0.0                    0.3          10.8
#
#    trip_duration
# 0      17.483333
# 1      16.166667
# 2       5.200000
# 3      11.083333
# 4      12.283333

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
#eremoving records where trip duration, trip distance and total fare amount are recorded as 0
dataset_v2 = dataset_[(dataset_['trip_duration'] !=0) & (dataset_['trip_distance']!=0) & (dataset_['total_amount']!=0)].reset_index(drop=True)

# %%
dataset_v2.shape
# Out:
# (1126633, 19)

# %%
dataset_v2.isnull().sum()
# Out:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# trip_duration            0
# dtype: int64

# %%
dataset_v2.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         2  2017-07-27 18:31:15   2017-07-27 18:48:44
# 1           1         1  2017-07-27 18:53:08   2017-07-27 19:09:18
# 2           2         1  2017-07-27 18:34:32   2017-07-27 18:39:44
# 3           3         2  2017-07-27 18:55:28   2017-07-27 19:06:33
# 4           4         2  2017-07-27 18:20:18   2017-07-27 18:32:35
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                2           2.25           1                  N
# 1                1           1.80           1                  N
# 2                1           0.60           1                  N
# 3                2           1.01           1                  N
# 4                1           1.18           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           230           246             2         13.0    1.0      0.5
# 1           246           230             1         11.5    1.0      0.5
# 2           141           262             1          5.0    1.0      0.5
# 3            43           141             2          8.0    1.0      0.5
# 4            48           164             2          9.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.0           0.0                    0.3          14.8
# 1         2.0           0.0                    0.3          15.3
# 2         1.0           0.0                    0.3           7.8
# 3         0.0           0.0                    0.3           9.8
# 4         0.0           0.0                    0.3          10.8
#
#    trip_duration
# 0      17.483333
# 1      16.166667
# 2       5.200000
# 3      11.083333
# 4      12.283333

# %%
#seapraring the dependent and independent variables
X = dataset_v2.iloc[:,1:-1]
y = dataset_v2.iloc[:,17]

# %%
X.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-07-27 18:31:15   2017-07-27 18:48:44                2
# 1         1  2017-07-27 18:53:08   2017-07-27 19:09:18                1
# 2         1  2017-07-27 18:34:32   2017-07-27 18:39:44                1
# 3         2  2017-07-27 18:55:28   2017-07-27 19:06:33                2
# 4         2  2017-07-27 18:20:18   2017-07-27 18:32:35                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.25           1                  N           230           246
# 1           1.80           1                  N           246           230
# 2           0.60           1                  N           141           262
# 3           1.01           1                  N            43           141
# 4           1.18           1                  N            48           164
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         13.0    1.0      0.5         0.0           0.0
# 1             1         11.5    1.0      0.5         2.0           0.0
# 2             1          5.0    1.0      0.5         1.0           0.0
# 3             2          8.0    1.0      0.5         0.0           0.0
# 4             2          9.0    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          14.8
# 1                    0.3          15.3
# 2                    0.3           7.8
# 3                    0.3           9.8
# 4                    0.3          10.8

# %%
y.head()
# Out:
# 0    14.8
# 1    15.3
# 2     7.8
# 3     9.8
# 4    10.8
# Name: total_amount, dtype: float64

# %%
#Drop the drop-off time column
X.drop(['tpep_dropoff_datetime'],axis=1,inplace =True)

# %%
X.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %% [markdown]
# **Feature Creation**

# %%
#Creating the time variables
X['pickup_day_no']=X['tpep_pickup_datetime'].dt.weekday
X['pickup_hour']=X['tpep_pickup_datetime'].dt.hour
X['pickup_month']=X['tpep_pickup_datetime'].dt.month

# %%
X.head()
# Out:
#    VendorID tpep_pickup_datetime  passenger_count  trip_distance  RatecodeID  \
# 0         2  2017-07-27 18:31:15                2           2.25           1
# 1         1  2017-07-27 18:53:08                1           1.80           1
# 2         1  2017-07-27 18:34:32                1           0.60           1
# 3         2  2017-07-27 18:55:28                2           1.01           1
# 4         2  2017-07-27 18:20:18                1           1.18           1
#
#   store_and_fwd_flag  PULocationID  DOLocationID  payment_type  fare_amount  \
# 0                  N           230           246             2         13.0
# 1                  N           246           230             1         11.5
# 2                  N           141           262             1          5.0
# 3                  N            43           141             2          8.0
# 4                  N            48           164             2          9.0
#
#    extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 0    1.0      0.5         0.0           0.0                    0.3
# 1    1.0      0.5         2.0           0.0                    0.3
# 2    1.0      0.5         1.0           0.0                    0.3
# 3    1.0      0.5         0.0           0.0                    0.3
# 4    1.0      0.5         0.0           0.0                    0.3
#
#    total_amount  pickup_day_no  pickup_hour  pickup_month
# 0          14.8              3           18             7
# 1          15.3              3           18             7
# 2           7.8              3           18             7
# 3           9.8              3           18             7
# 4          10.8              3           18             7

# %%
#Drop the pickup time stamp
X.drop(['tpep_pickup_datetime'],axis=1, inplace=True)

# %%
X.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0         2                2           2.25           1                  N
# 1         1                1           1.80           1                  N
# 2         1                1           0.60           1                  N
# 3         2                2           1.01           1                  N
# 4         2                1           1.18           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           230           246             2         13.0    1.0      0.5
# 1           246           230             1         11.5    1.0      0.5
# 2           141           262             1          5.0    1.0      0.5
# 3            43           141             2          8.0    1.0      0.5
# 4            48           164             2          9.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.0           0.0                    0.3          14.8
# 1         2.0           0.0                    0.3          15.3
# 2         1.0           0.0                    0.3           7.8
# 3         0.0           0.0                    0.3           9.8
# 4         0.0           0.0                    0.3          10.8
#
#    pickup_day_no  pickup_hour  pickup_month
# 0              3           18             7
# 1              3           18             7
# 2              3           18             7
# 3              3           18             7
# 4              3           18             7

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1126633 entries, 0 to 1126632
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1126633 non-null  int64
#  1   passenger_count        1126633 non-null  int64
#  2   trip_distance          1126633 non-null  float64
#  3   RatecodeID             1126633 non-null  int64
#  4   store_and_fwd_flag     1126633 non-null  object
#  5   PULocationID           1126633 non-null  int64
#  6   DOLocationID           1126633 non-null  int64
#  7   payment_type           1126633 non-null  int64
#  8   fare_amount            1126633 non-null  float64
#  9   extra                  1126633 non-null  float64
#  10  mta_tax                1126633 non-null  float64
#  11  tip_amount             1126633 non-null  float64
#  12  tolls_amount           1126633 non-null  float64
#  13  improvement_surcharge  1126633 non-null  float64
#  14  total_amount           1126633 non-null  float64
#  15  pickup_day_no          1126633 non-null  int32
#  16  pickup_hour            1126633 non-null  int32
#  17  pickup_month           1126633 non-null  int32
# dtypes: float64(8), int32(3), int64(6), object(1)
# memory usage: 141.8+ MB

# %%
X.isnull().sum()
# Out:
# VendorID                 0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_day_no            0
# pickup_hour              0
# pickup_month             0
# dtype: int64

# %% [markdown]
# **One hot Encoding the Store_and_flag column**

# %%
dummies = pd.get_dummies(X[['store_and_fwd_flag']],drop_first=True)
dummies
# Out:
#          store_and_fwd_flag_Y
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 1126628                 False
# 1126629                 False
# 1126630                 False
# 1126631                 False
# 1126632                 False
#
# [1126633 rows x 1 columns]

# %%
#concatenating
X1 = pd.concat([X,dummies],axis=1)

# %%
X1.drop(['store_and_fwd_flag'],axis=1,inplace=True)

# %%
X1.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0         2                2           2.25           1           230
# 1         1                1           1.80           1           246
# 2         1                1           0.60           1           141
# 3         2                2           1.01           1            43
# 4         2                1           1.18           1            48
#
#    DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0           246             2         13.0    1.0      0.5         0.0
# 1           230             1         11.5    1.0      0.5         2.0
# 2           262             1          5.0    1.0      0.5         1.0
# 3           141             2          8.0    1.0      0.5         0.0
# 4           164             2          9.0    1.0      0.5         0.0
#
#    tolls_amount  improvement_surcharge  total_amount  pickup_day_no  \
# 0           0.0                    0.3          14.8              3
# 1           0.0                    0.3          15.3              3
# 2           0.0                    0.3           7.8              3
# 3           0.0                    0.3           9.8              3
# 4           0.0                    0.3          10.8              3
#
#    pickup_hour  pickup_month  store_and_fwd_flag_Y
# 0           18             7                 False
# 1           18             7                 False
# 2           18             7                 False
# 3           18             7                 False
# 4           18             7                 False

# %% [markdown]
# ## Feature Scaling

# %%
#Performing feature scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X1)
# Out:
# MinMaxScaler()

# %%
#transforming
scaler.transform(X1)
# Out:
# array([[1.        , 0.22222222, 0.01740617, ..., 0.7826087 , 0.54545455,
#         0.        ],
#        [0.        , 0.11111111, 0.01390939, ..., 0.7826087 , 0.54545455,
#         0.        ],
#        [0.        , 0.11111111, 0.00458466, ..., 0.7826087 , 0.54545455,
#         0.        ],
#        ...,
#        [1.        , 0.22222222, 0.01196674, ..., 0.7826087 , 0.54545455,
#         0.        ],
#        [0.        , 0.11111111, 0.01002409, ..., 0.7826087 , 0.54545455,
#         0.        ],
#        [0.        , 0.22222222, 0.06519543, ..., 0.7826087 , 0.54545455,
#         0.        ]])

# %%
X2 = pd.DataFrame(scaler.transform(X1),columns=X1.columns)

# %%
X2.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0       1.0         0.222222       0.017406         0.0      0.867424
# 1       0.0         0.111111       0.013909         0.0      0.928030
# 2       0.0         0.111111       0.004585         0.0      0.530303
# 3       1.0         0.222222       0.007771         0.0      0.159091
# 4       1.0         0.111111       0.009092         0.0      0.178030
#
#    DOLocationID  payment_type  fare_amount     extra   mta_tax  tip_amount  \
# 0      0.928030      0.333333     0.172222  0.611111  0.740741    0.032381
# 1      0.867424      0.000000     0.169444  0.611111  0.740741    0.038513
# 2      0.988636      0.000000     0.157407  0.611111  0.740741    0.035447
# 3      0.530303      0.333333     0.162963  0.611111  0.740741    0.032381
# 4      0.617424      0.333333     0.164815  0.611111  0.740741    0.032381
#
#    tolls_amount  improvement_surcharge  total_amount  pickup_day_no  \
# 0           0.0                    1.0      0.092862            0.5
# 1           0.0                    1.0      0.093347            0.5
# 2           0.0                    1.0      0.086062            0.5
# 3           0.0                    1.0      0.088005            0.5
# 4           0.0                    1.0      0.088976            0.5
#
#    pickup_hour  pickup_month  store_and_fwd_flag_Y
# 0     0.782609      0.545455                   0.0
# 1     0.782609      0.545455                   0.0
# 2     0.782609      0.545455                   0.0
# 3     0.782609      0.545455                   0.0
# 4     0.782609      0.545455                   0.0

# %%
# Save the fitted scaler to a pickle file
import pickle
with open("..\Models\duration_scaler.pickle", "wb") as f:
    pickle.dump(scaler, f)

# %%
#saving the transformed dataframe to a csv file
X2.to_csv('X_transformed.csv',index=False)

# %%
X2.columns
# Out:
# Index(['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'pickup_day_no', 'pickup_hour', 'pickup_month',
#        'store_and_fwd_flag_Y'],
#       dtype='object')

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# The goal is to select the best features to use for predicting the trip duration

# %%
X2.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0       1.0         0.222222       0.017406         0.0      0.867424
# 1       0.0         0.111111       0.013909         0.0      0.928030
# 2       0.0         0.111111       0.004585         0.0      0.530303
# 3       1.0         0.222222       0.007771         0.0      0.159091
# 4       1.0         0.111111       0.009092         0.0      0.178030
#
#    DOLocationID  payment_type  fare_amount     extra   mta_tax  tip_amount  \
# 0      0.928030      0.333333     0.172222  0.611111  0.740741    0.032381
# 1      0.867424      0.000000     0.169444  0.611111  0.740741    0.038513
# 2      0.988636      0.000000     0.157407  0.611111  0.740741    0.035447
# 3      0.530303      0.333333     0.162963  0.611111  0.740741    0.032381
# 4      0.617424      0.333333     0.164815  0.611111  0.740741    0.032381
#
#    tolls_amount  improvement_surcharge  total_amount  pickup_day_no  \
# 0           0.0                    1.0      0.092862            0.5
# 1           0.0                    1.0      0.093347            0.5
# 2           0.0                    1.0      0.086062            0.5
# 3           0.0                    1.0      0.088005            0.5
# 4           0.0                    1.0      0.088976            0.5
#
#    pickup_hour  pickup_month  store_and_fwd_flag_Y
# 0     0.782609      0.545455                   0.0
# 1     0.782609      0.545455                   0.0
# 2     0.782609      0.545455                   0.0
# 3     0.782609      0.545455                   0.0
# 4     0.782609      0.545455                   0.0

# %%
X2.isnull().sum()
# Out:
# VendorID                 0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_day_no            0
# pickup_hour              0
# pickup_month             0
# store_and_fwd_flag_Y     0
# dtype: int64

# %%
y.head()
# Out:
# 0    14.8
# 1    15.3
# 2     7.8
# 3     9.8
# 4    10.8
# Name: total_amount, dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
#Splitting the dataset into train & test sets
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size = 0.2, random_state = 13)

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=13))
feature_sel_model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=13))

# %%
feature_sel_model.get_support()
# Out:
# array([False, False,  True,  True, False,  True,  True,  True,  True,
#        False, False, False, False,  True,  True,  True, False, False])

# %%
# this is how we can make a list of the selected features
selected_feat = X_train.columns[(feature_sel_model.get_support())]

# let's print some stats
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(np.sum(feature_sel_model.estimator_.coef_ == 0)))
# Out:
# total features: 18
# selected features: 9
# features with coefficients shrank to zero: 9

# %%
selected_feat
# Out:
# Index(['trip_distance', 'RatecodeID', 'DOLocationID', 'payment_type',
#        'fare_amount', 'extra', 'total_amount', 'pickup_day_no', 'pickup_hour'],
#       dtype='object')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
#Updating the data with the selected features
X3 = X2[['trip_distance', 'RatecodeID', 'DOLocationID', 'payment_type',
       'fare_amount', 'extra', 'pickup_day_no', 'pickup_hour']]

# %% [markdown]
# ## Model Building

# %% [markdown]
# **Baseline Models**

# %%
#Splitting the dataset into train & test sets
X_train, X_test, y_train, y_test = train_test_split(X3, y, test_size = 0.2, random_state = 13)

# %% [markdown]
# **Using Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
#Using linear regression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2_score=r2_score(y_test,y_pred)
print("r2 score is:",r2_score)
print("Mean Squared Error:", mse)
# Out:
# r2 score is: 0.9674931553647609
# Mean Squared Error: 6.184937692062397

# %% [markdown]
# Seems the model is overfitting when using total amount as part of the features selected. Hence we'll drop total_amount from the selected features

# %% [markdown]
# **Using Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
# Train the model on the training data
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions on the test data
y_pred = rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
#r2_score=r2_score(y_test,y_pred)
#print("r2 score is:",r2_score)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 4.53489573659905

# %% [markdown]
# **Using XGBoost Regressor**

# %%
#Using XGBoost Regressor
from xgboost import XGBRegressor
xg = XGBRegressor()
#Traiing tne model
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xg.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
#r2_score=r2_score(y_test,y_pred)
#print("r2 score is:",r2_score)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 6.706000777058182

# %% [markdown]
# From the above experiments, seems like the random forest regressor performs better, while the linear regresson model might have a tendency to overfit.

# %% [markdown]
# **Using Cross Validation**

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=13)

cross_val_score(rf,X3,y,cv=cv)

# %% [markdown]
# We can observe from the above 5 iterations using random forest regressor, we get an accuracy score above 99%.

# %% [markdown]
# **Using Grid Search CV**

# %%
from sklearn.model_selection import GridSearchCV

#Finding the best model to use
def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': lr,
            'params': {
                'normalize': [True, False]
            }
        },
        'random_forest': {
            'model': rf,
            'params': {
                'n_estimators': [10,25,50,100],
                'max_depth':[10,20,None],
                
            }
        },
        'xgboost': {
            'model': xg,
            'params': {
                'n_estimators': [10,25,50,100],
                'booster':['gbtree','gblinear','dart'],
                'max_depth':[5,10,20],
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X3,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)

# %% [markdown]
# ### **Feature Importance**
#
# The goal is to identify based on the selected model, which predictors are the most important

# %%
importances = rf.feature_importances_

# Print the importances for each feature
for feature, importance in zip(X_train.columns, importances):
    print(f"{feature}: {importance:.4f}")
# Out:
# trip_distance: 0.0116
# RatecodeID: 0.0003
# DOLocationID: 0.0056
# payment_type: 0.0132
# fare_amount: 0.9631
# extra: 0.0015
# pickup_day_no: 0.0018
# pickup_hour: 0.0029

# %%
# Create a bar chart of feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x=X_train.columns, y=importances)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importances in Random Forest Regressor")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exporting the model**

# %%
#Exporting the model to a pickle file
import pickle
with open('..\Models\predict_trip_duration.pickle','wb') as f:
    pickle.dump(rf,f)

# %% [markdown]
# Exporting the schema of the X_test data

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X3.columns]
}
with open("trip_duration_prediction_columns.json","w") as f:
    f.write(json.dumps(columns))
